# %%
print("sdadask")
# Out:
# sdadask

# %%
print("""I am Batman
Hello.
Harimau harimau harimau""")
# Out:
# I am Batman
# Hello.
# Harimau harimau harimau

# %%
print('''I am Batman
Hello.
Harimau harimau harimau''')
# Out:
# I am Batman
# Hello.
# Harimau harimau harimau

# %% [markdown]
# # Numeric

# %%
x = 5
print(x)
# Out:
# 5

# %%
type(x)
# Out:
# int

# %%
y = 3.14
print(y)
# Out:
# 3.14

# %%
print(x + y) # penjumlahan
print(x * y) # pengalian
print(x ** y) # pangkat
print(x / y) # pembagian1 - float
print(x // y) # pembagian2 - float
print(x % y) # modulo
print(x**0.5) # pangkat
# Out:
# 8.14
# 15.700000000000001
# 156.59064522818883
# 1.592356687898089
# 1.0
# 1.8599999999999999
# 2.23606797749979

# %%
import math
print(math.ceil(x/y))
print(math.floor(x/y))
print(math.pi)
# Out:
# 2
# 1
# 3.141592653589793

# %% [markdown]
# # Boolean

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
5 > 3
# Out:
# True

# %%
not 5 > 3
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
True + False
# Out:
# 1

# %%
True == 1
# Out:
# True

# %%
False == 0
# Out:
# True

# %%
if 5 > 3:
  print("Hello")
else:
  print("Bye")
# Out:
# Hello

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True and True
# Out:
# True

# %%
x = float(True)
x
# Out:
# 1.0

# %% [markdown]
# # Conditional Statement

# %%
# Operasi perbandingan melibatkan operator:
# > lebih dari
# < kurang dari
# >= lebih dari atau sama dengan
# <= kuranf dari atau sama dengan
# == sama dengan
# != tidak sama dengan
# operasi perbandingan akan menghasilkan True atau False

# %%
x = int(input("Masukkan nilai x: "))
if x > 4:
  print("Nilai x lebih dari 4")
elif x == 4:
  print("Nilai x sama dengan 4")
else:
  print("Nilai x kurang dari 4")
# Out:
# Masukkan nilai x: 4
# Nilai x sama dengan 4

# %%
x = int(input("Masukkan nilai x: "))
if x % 2 == 0:
  print("x bilangan genap")
else:
  print("x bilangan ganjil")
# Out:
# Masukkan nilai x: 5
# x bilangan ganjil

# %%
x = int(input("Masukkan nilai x: "))
y = int(input("Masukkan nilai y: "))
if (x % 2 == 0) and (y % 3 == 0):
  print("x dan y bilangan yang habis dibagi 2 dan 3")
else:
  print("salah satu dari x atau y adalah bilangan yang tidak habis dibagi 2 dan 3")
# Out:
# Masukkan nilai x: 4
# Masukkan nilai y: 5
# salah satu dari x atau y adalah bilangan yang tidak habis dibagi 2 dan 3

# %%
# bmi: body mass index
# weight (kg)
# height (cm)
# bmi = weight (kg) / height (m)^2
# kalau bmi kurang dari 18.5
 # print (bmi)
 # print ("anda underweight")
# kalau bmi lebih besar sama dengan 18.5 sampai  kurang dari 24.9
 # print (bmi)
 # print ("anda Healthy")
# kalau bmi lebih besar sama dengan 24.9 sampai  kurang dari 29.9 print ("anda Overweight")
# selain itu print ("anda obesitas")

# %%
# pseudo code
# python

# %%
# buatlah segitiga siku-siku berikut
# *
# **
# ***
# ****
# *****

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
list(range(1,6))
# Out:
# [1, 2, 3, 4, 5]

# %%
list(range(1,5,2))
# Out:
# [1, 3]

# %% [markdown]
# # String

# %%
print('Hello, World!')
print("Hello, Jum'at!")
print("""Hello, World!
I am Batman""")
# Out:
# Hello, World!
# Hello, Jum'at!
# Hello, World!
# I am Batman

# %%
"I am " + "Spiderman"
# Out:
# 'I am Spiderman'

# %%
"*" * 5
# Out:
# '*****'

# %%
"*" + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-2ae2acc4d3dc> in <cell line: 0>()
# ----> 1 "*" + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
"*" - 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-e8625250c143> in <cell line: 0>()
# ----> 1 "*" - 5
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
"*" / 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-a72adb1fa46a> in <cell line: 0>()
# ----> 1 "*" / 5
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
"*" ** 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-857e3ead6700> in <cell line: 0>()
# ----> 1 "*" ** 5
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
x = "PyThOn. SqL"

# %%
type(x)
# Out:
# str

# %%
x.upper()
# Out:
# 'PYTHON'

# %%
x.lower()
# Out:
# 'python'

# %%
x.capitalize()
# Out:
# 'Python. sql'

# %%
x.swapcase()
# Out:
# 'pYtHoN. sQl'

# %%
x.count("y")
# Out:
# 1

# %%
#0123456
#PyThOn. SqL
x.replace("O","a")
# Out:
# 'PyThan. SqL'

# %%
'      Aku suka belajar Python        '.strip()
# Out:
# 'Aku suka belajar Python'

# %%
x[0:6]
# Out:
# 'PyThOn'

# %%
for x in range(6):
  print(x * 2)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
_ = "halo"
print(_)
# Out:
# halo

# %%
nama = "Ridho Aryo Pratama".split()
nama_depan = nama[0]
nama_tengah = nama[1]
nama_belakang = nama[2]

# %%
nama_depan
# Out:
# 'Ridho'
