# %%
list_name = ['asep','amir', 'budi', 'cinta', 'edi', 'asep' ]

asep = []
for getIndex, getName in enumerate(list_name):
    if getName == 'asep':
        asep.append(getIndex)
print(asep)
# Out:
# [0, 5]

# %%
list_name = ['asep','amir', 'budi', 'cinta', 'edi', 'asep' ]
x = []
i = 0
for name in list_name:
  if name == 'budi':
    x.append(i)
  i += 1
print(x)
# Out:
# [2]

# %%
print(i)
# Out:
# 6

# %%
asep = [getIndex for getIndex, getName in enumerate(list_name) if getName == 'asep']
print(asep)
# Out:
# [0, 5]

# %%
bilangan = [2, 4, 3, 6, 7, 9]
bilangan_baru = []
for i in bilangan:
  if i % 2 == 0:
    bilangan_baru.append(i + 1)
  else:
    bilangan_baru.append(i + 2)
print(bilangan_baru)
# while or for are allowed
# logic
  # jika bilangan genap: tambah dengan 1
  # jika bilangan ganjil: tambah dengan 2
  # hasil penjumlahan masukkan dalam list yang baru
# result [3, 5, 5, 7, 9, 11]
# Out:
# [3, 5, 5, 7, 9, 11]

# %%
z = 2 # Global Variable (Variable di luar function)
def f():
  y = 1 # Local Variable (Variable di dalam function)
  return z

# f()

# %%
f()
# Out:
# 2

# %%
print(f())
# Out:
# 2

# %%
print(x_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-7643a3c69bae> in <cell line: 0>()
# ----> 1 print(x_)
#
# NameError: name 'x_' is not defined

# %%
bilangan = [2, 4, 3, 6, 7, 9]

def ganjil_genap(angka):
  bilangan_baru = []

  for i in angka:
      if i % 2 == 0:
          bilangan_baru.append(i+1)
      else:
          bilangan_baru.append(i+2)

  return bilangan_baru

print(ganjil_genap(bilangan))

# %%
print(i)
# Out:
# 9

# %%
i = 10
i = 5
i = 7

# %%
i = 9

# %%
i = 4

# %%
bilangan = [2, 4, 3, 6, 7, 9]
def ganjil_genap(i):
  if i % 2 == 0:
    return i+1
  else:
    return i+2

bilangan_baru = set(map(ganjil_genap, bilangan))
print(bilangan_baru)
# Out:
# {3, 5, 7, 9, 11}

# %%
for i in range(10):
  if i % 2 == 0:
    continue
  else:
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(10):
  if i % 2 == 0:
    print(i)
  else:
    break
# Out:
# 0
